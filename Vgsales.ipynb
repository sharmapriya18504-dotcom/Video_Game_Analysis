# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df1 = pd.read_csv("vgsales.csv")
df1
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df1.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  str
#  2   Platform      16598 non-null  str
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  str
#  5   Publisher     16540 non-null  str
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), str(4)
# memory usage: 1.4 MB

# %%
df1.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
## Year

df1["Year"] = df1["Year"].fillna(df1["Year"].median())

## Publisher

df1["Publisher"] = df1["Publisher"].fillna("Unknown")

# %%
## Covert year to int dtype

df1["Year"] = df1["Year"].astype(int)

# %%
df1.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df1.to_csv("clean_vgsales.csv", index=False, encoding="utf-8")

# %%
import pandas as pd
df = pd.read_csv("clean_games.csv")

# %%
import pandas as pd
df1 = pd.read_csv("clean_vgsales.csv")

# %% [markdown]
# ## Merging both datasets

# %%
print("df.columns:", df.columns)
print("df1.columns:", df1.columns)
# Out:
# df.columns: Index(['title', 'release_date', 'team', 'rating', 'times_listed',
#        'number_of_reviews', 'genres', 'summary', 'reviews', 'plays', 'playing',
#        'backlogs', 'wishlist'],
#       dtype='str')
# df1.columns: Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()
df1.columns = df1.columns.str.strip()

# %%
df.rename(columns={"title": "Name"}, inplace=True)

# %%
df["Name"] = df["Name"].str.lower().str.strip()
df1["Name"] = df1["Name"].str.lower().str.strip()

# %%
df2 = pd.merge(df, df1, on="Name", how="inner")

# %%
df2
# Out:
#                           Name  release_date                 team  rating  \
# 0                    minecraft  Nov 18, 2011       Mojang Studios     4.3
# 1                    minecraft  Nov 18, 2011       Mojang Studios     4.3
# 2                    minecraft  Nov 18, 2011       Mojang Studios     4.3
# 3                    minecraft  Nov 18, 2011       Mojang Studios     4.3
# 4                    minecraft  Nov 18, 2011       Mojang Studios     4.3
# ...                        ...           ...                  ...     ...
# 1302  the lego movie videogame  Feb 04, 2014  WB Games, TT Fusion     2.8
# 1303  the lego movie videogame  Feb 04, 2014  WB Games, TT Fusion     2.8
# 1304  the lego movie videogame  Feb 04, 2014  WB Games, TT Fusion     2.8
# 1305  the lego movie videogame  Feb 04, 2014  WB Games, TT Fusion     2.8
# 1306  the lego movie videogame  Feb 04, 2014  WB Games, TT Fusion     2.8
#
#       times_listed  number_of_reviews                genres  \
# ...

# %%
df2.head()
# Out:
#         Name  release_date            team  rating  times_listed  \
# 0  minecraft  Nov 18, 2011  Mojang Studios     4.3        2300.0
# 1  minecraft  Nov 18, 2011  Mojang Studios     4.3        2300.0
# 2  minecraft  Nov 18, 2011  Mojang Studios     4.3        2300.0
# 3  minecraft  Nov 18, 2011  Mojang Studios     4.3        2300.0
# 4  minecraft  Nov 18, 2011  Mojang Studios     4.3        2300.0
#
#    number_of_reviews                genres  \
# 0             2300.0  Adventure, Simulator
# 1             2300.0  Adventure, Simulator
# 2             2300.0  Adventure, Simulator
# 3             2300.0  Adventure, Simulator
# 4             2300.0  Adventure, Simulator
#
#                                              summary  \
# 0  Minecraft focuses on allowing the player to ex...
# 1  Minecraft focuses on allowing the player to ex...
# 2  Minecraft focuses on allowing the player to ex...
# 3  Minecraft focuses on allowing the player to ex...
# ...

# %%
df2.shape
# Out:
# (1307, 23)

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1307 entries, 0 to 1306
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1307 non-null   str
#  1   release_date       1307 non-null   str
#  2   team               1307 non-null   str
#  3   rating             1307 non-null   float64
#  4   times_listed       1307 non-null   float64
#  5   number_of_reviews  1307 non-null   float64
#  6   genres             1306 non-null   str
#  7   summary            1307 non-null   str
#  8   reviews            1307 non-null   str
#  9   plays              1307 non-null   float64
#  10  playing            1307 non-null   float64
#  11  backlogs           1307 non-null   float64
#  12  wishlist           1307 non-null   float64
#  13  Rank               1307 non-null   int64
#  14  Platform           1307 non-null   str
#  15  Year               1307 non-null   int64
# ...

# %%
df2.isna().sum()
# Out:
# Name                 0
# release_date         0
# team                 0
# rating               0
# times_listed         0
# number_of_reviews    0
# genres               1
# summary              0
# reviews              0
# plays                0
# playing              0
# backlogs             0
# wishlist             0
# Rank                 0
# Platform             0
# Year                 0
# Genre                0
# Publisher            0
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Other_Sales          0
# Global_Sales         0
# dtype: int64

# %%
df2["genres"] = df2["genres"].fillna("Unknown")

# %%
df2.isna().sum()
# Out:
# Name                 0
# release_date         0
# team                 0
# rating               0
# times_listed         0
# number_of_reviews    0
# genres               0
# summary              0
# reviews              0
# plays                0
# playing              0
# backlogs             0
# wishlist             0
# Rank                 0
# Platform             0
# Year                 0
# Genre                0
# Publisher            0
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Other_Sales          0
# Global_Sales         0
# dtype: int64

# %%
df2.drop(columns=["id"], errors='ignore', inplace=True)

# %%
df2.to_csv("merged_dataset.csv", index=False, encoding="utf-8")
